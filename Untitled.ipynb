# %%
# import py_entitymatching package
import py_entitymatching as em

# %%
path_A = '/u/z/h/zhenda/CS 638/tempA.csv'

# %%
A = em.read_csv_metadata(path_A, key='id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
path_B = '/u/z/h/zhenda/CS 638/tableB.csv'

# %%
B = em.read_csv_metadata(path_B,key='id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
#em.get_key(A)
em.get_key(B)
# Out:
# 'id'

# %%
ab = em.AttrEquivalenceBlocker()
C0 = ab.block_tables(B,A,'release_year','release_year',l_output_attrs=['title','release_year'],r_output_attrs=['title','release_year'])
C0
# Out:
#            _id  ltable_id  rtable_id                     ltable_title  \
# 0            0          0          1                        Undertale
# 1            1          0         17                        Undertale
# 2            2          0         20                        Undertale
# 3            3          0         39                        Undertale
# 4            4          0         59                        Undertale
# 5            5          0         62                        Undertale
# 6            6          0        121                        Undertale
# 7            7          0        127                        Undertale
# 8            8          0        138                        Undertale
# 9            9          0        176                        Undertale
# 10          10          0        179                        Undertale
# 11          11          0        203                        Undertale
# ...

# %%
ob = em.OverlapBlocker()
#C1 = ob.block_tables(A,B,'title','title',l_output_attrs=['title','release_year'],r_output_attrs=['title','release_year'],word_level=True, overlap_size=1)
C1 = ob.block_candset(C0,'title','title',word_level=True, overlap_size=1)
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:08

# %%
C1
# Out:
#            _id  ltable_id  rtable_id                          ltable_title  \
# 3            3          0         39                             Undertale
# 432        432          3          1                    Grand Theft Auto V
# 436        436          3         59                    Grand Theft Auto V
# 467        467          3        487                    Grand Theft Auto V
# 728        728          3       2758                    Grand Theft Auto V
# 799        799          3       3284                    Grand Theft Auto V
# 864        864          4          1  Metal Gear Solid V: The Phantom Pain
# 868        868          4         59  Metal Gear Solid V: The Phantom Pain
# 897        897          4        467  Metal Gear Solid V: The Phantom Pain
# 1020      1020          4       1699  Metal Gear Solid V: The Phantom Pain
# 1218      1218          4       3193  Metal Gear Solid V: The Phantom Pain
# ...

# %%
em.to_csv_metadata(C1,'./C1.csv')
# Out:
# File already exists at ./C1.csv; Overwriting it
# Metadata file already exists at ./C1.metadata. Overwriting it
# True

# %%
em.to_csv_metadata(C0,'./C0.csv')
# Out:
# File already exists at ./C0.csv; Overwriting it
# Metadata file already exists at ./C0.metadata. Overwriting it
# True
